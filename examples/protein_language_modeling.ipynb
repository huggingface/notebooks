# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install 🤗 Transformers as well as some other libraries. Uncomment the following cell and run it.

# %%
#! pip install transformers evaluate datasets requests pandas scikit-learn

# %% [markdown]
# If you're opening this notebook locally, make sure your environment has an install from the last version of those libraries.
#
# To be able to share your model with the community, there are a few more steps to follow.
#
# First you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!) then execute the following cell and input your token:

# %%
from huggingface_hub import notebook_login

notebook_login()

# %% [markdown]
# # Fine-Tuning Protein Language Models

# %% [markdown]
# In this notebook, we're going to do some transfer learning to fine-tune some large, pre-trained protein language models on tasks of interest. If that sentence feels a bit intimidating to you, don't panic - there's [a blog post](https://huggingface.co/blog/deep-learning-with-proteins) that explains the concepts here in much more detail.
#
# The specific model we're going to use is ESMC, a protein language model from the ESM family. The release announcement for this model is [ESM Cambrian (EvolutionaryScale, 2024)](https://www.evolutionaryscale.ai/blog/esm-cambrian).
#
# There are several ESMC checkpoints with differing model sizes. Larger models will generally have better accuracy, but they require more GPU memory and will take much longer to train. The available ESMC checkpoints are:
#
# | Checkpoint name | Num layers | Num parameters |
# |------------------------|----|------|
# | `biohub/ESMC-6B-hf`    | 80 | 6B   |
# | `biohub/ESMC-600M-hf`  | 36 | 600M |
# | `biohub/ESMC-300M-hf`  | 30 | 300M |
#
# One caution: each checkpoint also has a twin repo on the Hub *without* the `-hf` suffix, storing the weights in their original upstream format. Those **do not work with `transformers`** - make sure the checkpoint name you use ends in `-hf`!
#
# Note that the larger checkpoints may be very difficult to train without a large cloud GPU like an A100 or H100, and that memory usage for attention during training will scale as `O(batch_size * num_layers * seq_len^2)`, so larger models on long sequences will use quite a lot of memory! We will use the `biohub/ESMC-300M-hf` checkpoint for this notebook, which should train on any modern GPU.

# %%
model_checkpoint = "biohub/ESMC-300M-hf"

# %% [markdown]
# # Sequence classification

# %% [markdown]
# One of the most common tasks you can perform with a language model is **sequence classification**. In sequence classification, we classify an entire protein into a category, from a list of two or more possibilities. There's no limit on the number of categories you can use, or the specific problem you choose, as long as it's something the model could in theory infer from the raw protein sequence. To keep things simple for this example, though, let's try classifying proteins by their **subcellular localization** - given its sequence, can we predict which compartment of the cell a protein will be found in?

# %% [markdown]
# ## Data preparation

# %% [markdown]
# In this section, we're going to gather some training data from UniProt. Our goal is to create a pair of lists: `sequences` and `labels`. `sequences` will be a list of protein sequences, which will just be strings like "MNKL...", where each letter represents a single amino acid in the complete protein. `labels` will be a list of the category for each sequence. The categories will just be integers, with 0 representing the first category, 1 representing the second and so on. In other words, if `sequences[i]` is a protein sequence then `labels[i]` should be its corresponding category. These will form the **training data** we're going to use to teach the model the task we want it to do.
#
# If you're adapting this notebook for your own use, this will probably be the main section you want to change! You can do whatever you want here, as long as you create those two lists by the end of it. If you want to follow along with this example, though, first we'll need to `import requests` and set up our query to UniProt.

# %%
import requests

query_url ="https://rest.uniprot.org/uniprotkb/stream?compressed=true&fields=accession%2Csequence%2Ccc_subcellular_location&format=tsv&query=%28%28organism_id%3A9606%29%20AND%20%28reviewed%3Atrue%29%20AND%20%28length%3A%5B80%20TO%20500%5D%29%29"

# %% [markdown]
# This query URL might seem mysterious, but it isn't! To get it, we searched for `(organism_id:9606) AND (reviewed:true) AND (length:[80 TO 500])` on UniProt to get a list of reasonably-sized human proteins,
# then selected 'Download', and set the format to TSV and the columns to `Sequence` and `Subcellular location [CC]`, since those contain the data we care about for this task.
#
# Once that's done, selecting `Generate URL for API` gives you a URL you can pass to Requests. Alternatively, if you're not on Colab you can just download the data through the web interface and open the file locally.

# %%
uniprot_request = requests.get(query_url)

# %% [markdown]
# To get this data into Pandas, we use a `BytesIO` object, which Pandas will treat like a file. If you downloaded the data as a file you can skip this bit and just pass the filepath directly to `read_csv`.

# %%
from io import BytesIO
import pandas

bio = BytesIO(uniprot_request.content)

df = pandas.read_csv(bio, compression='gzip', sep='\t')
df

# %% [markdown]
# Nice! Now we have some proteins and their subcellular locations. Let's start filtering this down. First, let's ditch the columns without subcellular location information.

# %%
df = df.dropna()  # Drop proteins with missing columns

# %% [markdown]
# Now let's assign each protein to a cellular compartment. We'll use six classes, taken from the standard vocabulary of the [DeepLoc](https://services.healthtech.dtu.dk/services/DeepLoc-1.0/) subcellular localization benchmark: cytoplasm, nucleus, cell membrane, mitochondrion, extracellular and endoplasmic reticulum. (DeepLoc's full taxonomy has ten classes, but the other four are rare or absent in a human-only dataset, so we skip them here. Note also that UniProt's term for extracellular proteins is `Secreted`.)
#
# Many proteins are annotated with more than one location - to keep our labels unambiguous, we only keep proteins that match exactly one of the six compartments.

# %%
import numpy as np

CLASSES = {
    "Cytoplasm":             ["Cytoplasm", "Cytosol"],
    "Nucleus":               ["Nucleus"],
    "Cell membrane":         ["Cell membrane"],
    "Mitochondrion":         ["Mitochondrion"],
    "Extracellular":         ["Secreted"],
    "Endoplasmic reticulum": ["Endoplasmic reticulum"],
}

col = df["Subcellular location [CC]"]
hits = np.stack(
    [np.logical_or.reduce([col.str.contains(term, case=False, regex=False).values for term in terms])
     for terms in CLASSES.values()],
    axis=1,
)
keep = hits.sum(axis=1) == 1  # Keep proteins matching exactly one compartment
sequences = df["Sequence"][keep].tolist()
labels = hits[keep].argmax(axis=1).tolist()

# %% [markdown]
# Let's see how many proteins we end up with, and how they're distributed across our classes:

# %%
class_names = list(CLASSES)
for name, count in zip(class_names, np.bincount(labels)):
    print(f"{name}: {count}")
print(f"Total: {len(sequences)}")

# %% [markdown]
# Notice that the classes aren't balanced - there are four times as many nuclear proteins as endoplasmic reticulum ones. That's worth remembering when we evaluate our model later! Our `sequences` and `labels` lists are now ready - don't worry about the ordering, they'll get shuffled during training.

# %% [markdown]
# ## Splitting the data

# %% [markdown]
# Since the data we're loading isn't prepared for us as a machine learning dataset, we'll have to split the data into train and test sets ourselves! We can use sklearn's function for that.
#
# One caveat: a random split is a little too easy here, because human proteins come in families of similar sequences, so near-duplicates of some training proteins will end up in the test set. Careful protein benchmarks instead split by **homology**, keeping similar sequences on the same side of the split - we'll see an example in the token classification task. For a quick demo, though, a random split is fine.

# %%
from sklearn.model_selection import train_test_split

train_sequences, test_sequences, train_labels, test_labels = train_test_split(sequences, labels, test_size=0.25, shuffle=True)

# %% [markdown]
# ## Tokenizing the data

# %% [markdown]
# All inputs to neural nets must be numerical. The process of converting strings into numerical indices suitable for a neural net is called **tokenization**. For natural language this can be quite complex, as usually the network's vocabulary will not contain every possible word, which means the tokenizer must handle splitting rarer words into pieces, as well as all the complexities of capitalization and unicode characters and so on.
#
# With proteins, however, things are very easy. In protein language models, each amino acid is converted to a single token. Every model on `transformers` comes with an associated `tokenizer` that handles tokenization for it, and protein language models are no different. Let's get our tokenizer!

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %% [markdown]
# Let's try a single sequence to see what the outputs from our tokenizer look like:

# %%
tokenizer(train_sequences[0])

# %% [markdown]
# This looks good! We can see that our sequence has been converted into `input_ids`, which is the tokenized sequence, and an `attention_mask`. The attention mask handles the case when we have sequences of variable length - in those cases, the shorter sequences are padded with blank "padding" tokens, and the attention mask is padded with 0s to indicate that those tokens should be ignored by the model.
#
# Notice that the tokenizer has also added two tokens that aren't amino acids: a `<cls>` token at the start and an `<eos>` token at the end. These special tokens don't matter for sequence classification, but they'll become important later, in the token classification task!
#
# So now, let's tokenize our whole dataset. Note that we don't need to do anything with the labels, as they're already in the format we need.

# %%
train_tokenized = tokenizer(train_sequences)
test_tokenized = tokenizer(test_sequences)

# %% [markdown]
# ## Dataset creation

# %% [markdown]
# Now we want to turn this data into a dataset that PyTorch can load samples from. We can use the HuggingFace `Dataset` class for this, although if you prefer you can also use `torch.utils.data.Dataset`, at the cost of some more boilerplate code.

# %%
from datasets import Dataset
train_dataset = Dataset.from_dict(train_tokenized)
test_dataset = Dataset.from_dict(test_tokenized)

train_dataset

# %% [markdown]
# This looks good, but we're missing our labels! Let's add those on as an extra column to the datasets.

# %%
train_dataset = train_dataset.add_column("labels", train_labels)
test_dataset = test_dataset.add_column("labels", test_labels)
train_dataset

# %% [markdown]
# Looks good! We're ready for training.

# %% [markdown]
# ## Model loading

# %% [markdown]
# Next, we want to load our model. Make sure to use exactly the same model as you used when loading the tokenizer, or your model might not understand the tokenization scheme you're using!

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

num_labels = max(train_labels + test_labels) + 1  # Add 1 since 0 can be a label
model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=num_labels)

# %% [markdown]
# These warnings are telling us that the model is discarding some weights that it used for language modelling (the `lm_head`) and adding some weights for sequence classification (the `score` head). This is exactly what we expect when we want to fine-tune a language model on a sequence classification task!
#
# Next, we initialize our `TrainingArguments`. These control the various training hyperparameters, and will be passed to our `Trainer`. Note that we set `bf16=True` to train in mixed precision - it's much faster and uses far less memory than full `float32` precision, with no real downside. If your GPU is older and doesn't support `bf16`, set `fp16=True` instead.

# %%
model_name = model_checkpoint.split("/")[-1]
batch_size = 8

args = TrainingArguments(
    f"{model_name}-finetuned-localization",
    eval_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    bf16=True,
    push_to_hub=True,
)

# %% [markdown]
# Next, we define the metric we will use to evaluate our models and write a `compute_metrics` function. We can load this from the `evaluate` library.

# %%
from evaluate import load
import numpy as np

metric = load("accuracy")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels)

# %% [markdown]
# And at last we're ready to initialize our `Trainer`:

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    processing_class=tokenizer,
    compute_metrics=compute_metrics,
)

# %% [markdown]
# You might wonder why we pass along the tokenizer as the `processing_class` when we already preprocessed our data. This is because we will use it one last time to make all the samples we gather the same length by applying padding, which requires knowing the model's preferences regarding padding (to the left or right? with which token?). The tokenizer has a pad method that will do all of this right for us, and the `Trainer` will use it. You can customize this part by defining and passing your own `data_collator`, which will receive samples like the dictionaries seen above and will need to return a dictionary of tensors.

# %% [markdown]
# Before we train, let's ask an important question: what accuracy would we get *without* the language model? A metric reported on its own is close to meaningless - 90% accuracy might be brilliant or terrible depending on the task. A quick, cheap **baseline** tells us what a trivial model scores, and that's the number to beat. We'll compute two: always predicting the most common class, and a logistic regression on each protein's amino acid composition.

# %%
from collections import Counter
from sklearn.linear_model import LogisticRegression

AMINO_ACIDS = "ACDEFGHIKLMNPQRSTVWY"

def composition(sequence):
    counts = Counter(sequence)
    return [counts[aa] / len(sequence) for aa in AMINO_ACIDS] + [len(sequence) / 500]

majority_class = np.bincount(train_labels).argmax()
print(f"Majority class baseline: {np.mean(np.array(test_labels) == majority_class):.3f}")

logreg = LogisticRegression(max_iter=1000)
logreg.fit([composition(s) for s in train_sequences], train_labels)
print(f"Amino acid composition baseline: {logreg.score([composition(s) for s in test_sequences], test_labels):.3f}")

# %% [markdown]
# We can now finetune our model by just calling the `train` method:

# %%
trainer.train()

# %% [markdown]
# Nice! After three epochs we have a model accuracy of ~87% - far above both of our baselines, so the pretrained model is clearly earning its keep. Note that we didn't do a lot of work to filter the training data or tune hyperparameters for this experiment, so accuracy could almost certainly go higher still.
#
# Overall accuracy isn't the full story when classes are imbalanced like ours, though - let's also look at how the model does on each class individually.

# %%
from sklearn.metrics import classification_report

predictions = trainer.predict(test_dataset).predictions.argmax(axis=1)
print(classification_report(test_labels, predictions, target_names=class_names))

# %% [markdown]
# The pattern here is worth understanding: extracellular and cell membrane proteins are the easiest classes, because those compartments stamp their proteins with strong local sequence signals - a signal peptide, or long hydrophobic transmembrane stretches. Cytoplasmic and endoplasmic reticulum proteins lack such a clean signature, and are the hardest classes. Per-class scores that split like this are often telling you something about the underlying biology!

# %% [markdown]
# ***
# # Token classification

# %% [markdown]
# Another common language model task is **token classification**. In this task, instead of classifying the whole sequence into a single category, we categorize each token (amino acid, in this case!) into one or more categories. This kind of model could be useful for:
#
# - Predicting secondary structure
# - Predicting buried vs. exposed residues
# - Predicting residues that will receive post-translational modifications
# - Predicting residues involved in binding pockets or active sites
# - Probably several other things, it's been a while since I was a postdoc

# %% [markdown]
# ## Data preparation

# %% [markdown]
# As in the sequence classification example, we aim to create two lists: `sequences` and `labels`. Unlike in that example, however, the `labels` are more than just single integers. Instead, the label for each sample will be **one integer per token in the input**. This should make sense - when we do token classification, different tokens in the input may have different categories!
#
# To demonstrate token classification, we're going to predict protein **secondary structure**: for each amino acid, is it part of an alpha helix, a beta strand, or neither? This time, instead of building a dataset ourselves, we'll load one from the Hugging Face Hub: the training data of the NetSurfP-2.0 secondary structure predictor, where every residue resolved in an experimental structure carries a label assigned by a program called DSSP. It also ships with standard benchmark test sets. We'll evaluate on **CB513**, which was filtered so that no test sequence is more than 25% identical to any training sequence - remember the homology problem from the first task? This is the standard solution, and it means you can compare your results directly against published numbers on the same benchmark!

# %%
from datasets import load_dataset

data = load_dataset("lamm-mit/protein-secondary-structure-netsurfp")
data

# %% [markdown]
# Let's take a look at one sample:

# %%
print(data["train"][0]["sequence"][:60])
print(data["train"][0]["labels"][:60])

# %% [markdown]
# The `labels` string runs parallel to the sequence: `H` means alpha helix, `E` means beta strand, and `C` means neither ("coil"). In the test sets, residues that were never resolved in the experimental structure are marked with a `.` - we don't know their true label, so we assign those positions the special value `-100`, which tells PyTorch's loss function to ignore them entirely.
#
# One more thing to handle, and it's subtle but important: remember the `<cls>` and `<eos>` tokens the tokenizer adds? The model makes a prediction for them too, so they each need an entry in the labels array. If we forget them, every label is silently shifted by one position, and each residue trains against its neighbour's label! Adding a `-100` at both ends keeps everything aligned.
#
# Finally, we'll truncate the rare very long sequences to 1024 tokens, since attention memory usage grows with the square of sequence length. Only about 1% of the training sequences are longer than this, and no CB513 sequence is affected - so our benchmark number stays honest.

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

LABEL_MAP = {"C": 0, "H": 1, "E": 2}
MAX_LENGTH = 1024

def tokenize_and_align(batch):
    tokenized = tokenizer(batch["sequence"], truncation=True, max_length=MAX_LENGTH)
    tokenized["labels"] = [
        [-100] + [LABEL_MAP.get(char, -100) for char in label_str][:MAX_LENGTH - 2] + [-100]
        for label_str in batch["labels"]
    ]
    return tokenized

train_dataset = data["train"].map(tokenize_and_align, batched=True, remove_columns=data["train"].column_names)
test_dataset = data["cb513"].map(tokenize_and_align, batched=True, remove_columns=data["cb513"].column_names)

# %% [markdown]
# ## Model loading

# %% [markdown]
# Before we load our new model, let's free the GPU memory held by the first one - the model and the `Trainer` (which keeps the optimizer state alive) are still resident, and they can crowd out the model we're about to train.

# %%
import gc
import torch

del model, trainer
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# The key difference here with the above example is that we use `AutoModelForTokenClassification` instead of `AutoModelForSequenceClassification`. We will also need a `data_collator` this time, as we're in the slightly more complex case where both inputs and labels must be padded in each batch.

# %%
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer

num_labels = 3
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=num_labels)

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer)

# %% [markdown]
# Now we set up our `TrainingArguments` as before.

# %%
model_name = model_checkpoint.split("/")[-1]
batch_size = 8

args = TrainingArguments(
    f"{model_name}-finetuned-secondary-structure",
    eval_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=1e-4,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.001,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    bf16=True,
    push_to_hub=True,
)

# %% [markdown]
# Our `compute_metrics` function is a bit more complex than in the sequence classification task, as we need to ignore any position where the label is `-100` - that covers the padding tokens, the `<cls>` and `<eos>` tokens, and the unresolved residues we masked out earlier.

# %%
from evaluate import load
import numpy as np

metric = load("accuracy")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    labels = labels.reshape((-1,))
    predictions = np.argmax(predictions, axis=2)
    predictions = predictions.reshape((-1,))
    predictions = predictions[labels!=-100]
    labels = labels[labels!=-100]
    return metric.compute(predictions=predictions, references=labels)

# %% [markdown]
# As before, let's establish a baseline before we train. Secondary structure classes are quite imbalanced, so let's see what accuracy we'd score on CB513 by predicting the most common class everywhere:

# %%
from collections import Counter

majority_char = Counter("".join(data["train"]["labels"])).most_common(1)[0][0]
test_counts = Counter("".join(data["cb513"]["labels"]))
valid_total = sum(test_counts[char] for char in LABEL_MAP)
print(f"Most common class: {majority_char}")
print(f"Majority class baseline: {test_counts[majority_char] / valid_total:.3f}")

# %% [markdown]
# And now we're ready to train our model!

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    processing_class=tokenizer,
    compute_metrics=compute_metrics,
    data_collator=data_collator,
)

trainer.train()

# %% [markdown]
# This task definitely seems harder than the first one, but we still reach an accuracy of ~87% - double the majority-class baseline, on a benchmark where no test protein closely resembles anything the model saw during fine-tuning. And because CB513 is a standard benchmark, you can compare that number directly against published secondary structure predictors! Remember that to keep this demo lightweight, we used one of the smallest ESMC models and didn't tune any hyperparameters. With a bigger model and a little more effort, accuracy on this task can go a lot higher.
